# %%
# !pip install --pre --upgrade bigdl-llm[all]
# Out:
# Collecting bigdl-llm[all]
#   Downloading bigdl_llm-2.5.0b20240322-py3-none-manylinux2010_x86_64.whl (13.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 27.8 MB/s eta 0:00:00
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from bigdl-llm[all]) (9.0.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from bigdl-llm[all]) (3.20.3)
# Requirement already satisfied: mpmath==1.3.0 in /usr/local/lib/python3.10/dist-packages (from bigdl-llm[all]) (1.3.0)
# Collecting numpy==1.26.4 (from bigdl-llm[all])
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 41.0 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bigdl-llm[all]) (2.2.1+cu121)
# Collecting transformers==4.31.0 (from bigdl-llm[all])
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 75.2 MB/s eta 0:00:00
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from bigdl-llm[all]) (0.1.99)
# Collecting tokenizers==0.13.3 (from bigdl-llm[all])
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 73.0 MB/s eta 0:00:00
# Collecting accelerate==0.21.0 (from bigdl-llm[all])
#   Downloading accelerate-0.21.0-py3-none-any.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 24.5 MB/s eta 0:00:00
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from bigdl-llm[all]) (0.9.0)
# Requirement already satisfied: intel-openmp in /usr/local/lib/python3.10/dist-packages (from bigdl-llm[all]) (2023.2.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.21.0->bigdl-llm[all]) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.21.0->bigdl-llm[all]) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate==0.21.0->bigdl-llm[all]) (6.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0->bigdl-llm[all]) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0->bigdl-llm[all]) (0.20.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0->bigdl-llm[all]) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0->bigdl-llm[all]) (2.31.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0->bigdl-llm[all]) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.31.0->bigdl-llm[all]) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->bigdl-llm[all]) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->bigdl-llm[all]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bigdl-llm[all]) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bigdl-llm[all]) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->bigdl-llm[all]) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->bigdl-llm[all])
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 46.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->bigdl-llm[all])
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 38.7 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->bigdl-llm[all])
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 34.7 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->bigdl-llm[all])
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.8 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->bigdl-llm[all])
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.5 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->bigdl-llm[all])
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 10.8 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->bigdl-llm[all])
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 22.5 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->bigdl-llm[all])
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 4.2 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->bigdl-llm[all])
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 3.4 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch->bigdl-llm[all])
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.6 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->bigdl-llm[all])
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->bigdl-llm[all]) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->bigdl-llm[all])
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 62.0 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bigdl-llm[all]) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0->bigdl-llm[all]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0->bigdl-llm[all]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0->bigdl-llm[all]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.31.0->bigdl-llm[all]) (2024.2.2)
# Installing collected packages: tokenizers, bigdl-llm, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, nvidia-cusparse-cu12, nvidia-cudnn-cu12, transformers, nvidia-cusolver-cu12, accelerate
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.2
#     Uninstalling tokenizers-0.15.2:
#       Successfully uninstalled tokenizers-0.15.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.38.2
#     Uninstalling transformers-4.38.2:
#       Successfully uninstalled transformers-4.38.2
# Successfully installed accelerate-0.21.0 bigdl-llm-2.5.0b20240322 numpy-1.26.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 tokenizers-0.13.3 transformers-4.31.0

# %%
import warnings
warnings.filterwarnings ("ignore")

import torch

from bigdl.llm.transformers import AutoModel

model_path = "THUDM/chatglm3-6b"

model = AutoModel.from_pretrained(model_path,
                                  load_in_4bit=True,
                                  trust_remote_code=True)
# Out:
# config.json:   0%|          | 0.00/1.32k [00:00<?, ?B/s]
# configuration_chatglm.py:   0%|          | 0.00/2.33k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/THUDM/chatglm3-6b:
# - configuration_chatglm.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_chatglm.py:   0%|          | 0.00/55.9k [00:00<?, ?B/s]
# quantization.py:   0%|          | 0.00/14.7k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/THUDM/chatglm3-6b:
# - quantization.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/THUDM/chatglm3-6b:
# - modeling_chatglm.py
# - quantization.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors.index.json:   0%|          | 0.00/21.2k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/7 [00:00<?, ?it/s]
# model-00001-of-00007.safetensors:   0%|          | 0.00/1.83G [00:00<?, ?B/s]
# model-00002-of-00007.safetensors:   0%|          | 0.00/1.97G [00:00<?, ?B/s]
# model-00003-of-00007.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00004-of-00007.safetensors:   0%|          | 0.00/1.82G [00:00<?, ?B/s]
# model-00005-of-00007.safetensors:   0%|          | 0.00/1.97G [00:00<?, ?B/s]
# model-00006-of-00007.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00007-of-00007.safetensors:   0%|          | 0.00/1.05G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
save_path = "./saved_path"
model.save_low_bit(save_path)

# %%
from bigdl.llm.transformers import AutoModelForCausalLM

model = AutoModelForCausalLM.load_low_bit(save_path)
# Out:
# Loading ./saved_path requires to execute some code in that repo, you can inspect the content of the repository at https://hf.co/./saved_path. You can dismiss this prompt by passing `trust_remote_code=True`.
# Do you accept? [y/N] y
# Loading ./saved_path requires to execute some code in that repo, you can inspect the content of the repository at https://hf.co/./saved_path. You can dismiss this prompt by passing `trust_remote_code=True`.
# Do you accept? [y/N] y

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(model_path,
                                          trust_remote_code=True)

CHATGLM_V2_PROMPT_TEMPLATE = "问:{prompt}\n\n中文回答:"

n_predict = 32 #max_new_tokens parameter in the generate function defines the maximum number of tokens to predict.
# Out:
# WARNING:transformers_modules.THUDM.chatglm3-6b.9addbe01105ca1939dd60a0e5866a1812be9daea.tokenization_chatglm:Setting eos_token is not supported, use the default one.
# WARNING:transformers_modules.THUDM.chatglm3-6b.9addbe01105ca1939dd60a0e5866a1812be9daea.tokenization_chatglm:Setting pad_token is not supported, use the default one.
# WARNING:transformers_modules.THUDM.chatglm3-6b.9addbe01105ca1939dd60a0e5866a1812be9daea.tokenization_chatglm:Setting unk_token is not supported, use the default one.

# %%
from transformers import EncoderDecoderModel

PRETRAINED = "raynardj/wenyanwen-chinese-translate-to-ancient"

trans_tokenizer = AutoTokenizer.from_pretrained(PRETRAINED)
trans_model = EncoderDecoderModel.from_pretrained(PRETRAINED)

# %%
def inference(text):
    tk_kwargs = dict(
      truncation=True,
      max_length=256,
      padding="max_length",
      return_tensors='pt')

    inputs = trans_tokenizer([text,],**tk_kwargs)
    with torch.no_grad():
        return trans_tokenizer.batch_decode(
            trans_model.generate(
            inputs.input_ids,
            attention_mask=inputs.attention_mask,
            num_beams=3,
            max_length=512,
            bos_token_id=101,
            eos_token_id=102,
            pad_token_id=tokenizer.pad_token_id,
        ), skip_special_tokens=True)

# %%
def get_answer(prompt):
  with torch.inference_mode():
    prompt = CHATGLM_V2_PROMPT_TEMPLATE.format(prompt=prompt)
    input_ids = tokenizer.encode(prompt, return_tensors="pt")
    output = model.generate(input_ids,
                            max_new_tokens=n_predict)
    res = tokenizer.decode(output[0], skip_special_tokens=True)
    return res[len(prompt)+11:]

# %%
prompt = input("今天想和我聊点什么呢？\n")
res = get_answer(prompt)
print(inference(res))
# Out:
# 今天想和我聊点什么呢？
# 什么是鸣金收兵？
# ['鸣 金 收 兵 者 ， 古 战 争 之 术 也 ， 谓 金 收 兵 ， 胜 归 我 ， 发 鸣 金 令 ， 使 士 卒 出 之 。']
